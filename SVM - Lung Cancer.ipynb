# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#import CSV
lung_cancer = pd.read_csv('cancer_patient.csv')

# %%
lung_cancer
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
#find count of columns, ids, and df size

lung_cancer.shape
lung_cancer.size
lung_cancer.count()
# Out:
# index                       1000
# Patient Id                  1000
# Age                         1000
# Gender                      1000
# Air Pollution               1000
# Alcohol use                 1000
# Dust Allergy                1000
# OccuPational Hazards        1000
# Genetic Risk                1000
# chronic Lung Disease        1000
# Balanced Diet               1000
# Obesity                     1000
# Smoking                     1000
# Passive Smoker              1000
# Chest Pain                  1000
# Coughing of Blood           1000
# Fatigue                     1000
# Weight Loss                 1000
# Shortness of Breath         1000
# Wheezing                    1000
# Swallowing Difficulty       1000
# Clubbing of Finger Nails    1000
# Frequent Cold               1000
# Dry Cough                   1000
# Snoring                     1000
# Level                       1000
# dtype: int64

# %%
#specific column count
lung_cancer['Coughing of Blood'].value_counts()
# Out:
# 7    187
# 4    172
# 3    171
# 2    121
# 8    119
# 1     71
# 9     60
# 5     50
# 6     49
# Name: Coughing of Blood, dtype: int64

# %%
high_df = lung_cancer[lung_cancer['Level']=='High'][0:500]
medium_df = lung_cancer[lung_cancer['Level']=='Medium'][0:500]
low_df = lung_cancer[lung_cancer['Level']=='Low'][0:500]

#help(high_df.plot)

# %%
high_ax = high_df.plot(kind='scatter', x='Wheezing', y='Coughing of Blood', color='blue', label='High')
med_ax = medium_df.plot(kind='scatter', x='Wheezing', y='Coughing of Blood', color='red', label='Medium', ax=high_ax)
low_ax = low_df.plot(kind='scatter', x='Wheezing', y='Coughing of Blood', color='green', label='Low', ax = med_ax)

plt.savefig("combined graph.png")

# %%
lung_cancer
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
lung_cancer.columns

feature_df = lung_cancer[['Age', 'Gender', 'Air Pollution', 'Alcohol use',
       'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
       'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
       'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
       'Weight Loss', 'Shortness of Breath', 'Wheezing',
       'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
       'Dry Cough', 'Snoring']]

x=np.asarray(feature_df)
y=np.asarray(lung_cancer['Coughing of Blood'])

x[0:500]
y[0:500]
# Out:
# array([4, 3, 8, 8, 9, 8, 4, 1, 5, 4, 7, 7, 6, 8, 2, 5, 3, 8, 7, 5, 6, 8,
#        9, 7, 7, 3, 4, 3, 7, 2, 6, 3, 7, 4, 1, 5, 2, 8, 4, 2, 1, 3, 4, 2,
#        2, 2, 6, 4, 1, 1, 2, 4, 6, 1, 3, 5, 1, 8, 2, 4, 2, 5, 3, 4, 3, 4,
#        3, 7, 9, 2, 4, 3, 4, 3, 3, 4, 3, 7, 2, 7, 4, 3, 3, 4, 3, 4, 3, 7,
#        7, 7, 3, 6, 8, 9, 7, 8, 7, 7, 7, 8, 9, 4, 8, 9, 7, 8, 7, 7, 7, 8,
#        9, 8, 1, 3, 9, 8, 8, 4, 1, 5, 4, 7, 7, 6, 7, 2, 5, 3, 8, 7, 5, 6,
#        8, 9, 7, 2, 3, 4, 3, 7, 2, 6, 3, 7, 4, 1, 6, 2, 8, 4, 2, 1, 3, 4,
#        2, 2, 2, 3, 4, 1, 1, 2, 4, 6, 1, 3, 5, 1, 7, 2, 4, 2, 5, 3, 4, 3,
#        4, 3, 7, 4, 2, 4, 3, 4, 3, 3, 4, 3, 7, 2, 1, 4, 3, 3, 4, 3, 4, 3,
#        7, 7, 7, 2, 6, 8, 9, 7, 8, 7, 7, 7, 8, 9, 8, 8, 9, 7, 8, 7, 7, 7,
#        8, 9, 8, 5, 4, 9, 8, 8, 4, 1, 5, 4, 7, 7, 6, 2, 2, 5, 3, 8, 7, 5,
#        6, 8, 9, 7, 1, 3, 4, 3, 7, 2, 6, 3, 7, 4, 1, 3, 2, 8, 4, 2, 1, 3,
#        4, 2, 2, 2, 4, 4, 1, 1, 2, 4, 6, 1, 3, 5, 1, 2, 2, 4, 2, 5, 3, 4,
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=100)

#100 x 9
X_train.shape

#100 x 1
y_train.shape

#900 x 23
X_test.shape

#900
y_test.shape
# Out:
# (500,)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn import svm

classifier = svm.SVC(kernel='linear', gamma='auto', C=2 )
classifier.fit(X_train, y_train)

y_predict = classifier.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        35
#            2       1.00      1.00      1.00        65
#            3       1.00      1.00      1.00        78
#            4       1.00      1.00      1.00        87
#            5       1.00      1.00      1.00        22
#            6       1.00      1.00      1.00        21
#            7       1.00      1.00      1.00        94
#            8       1.00      1.00      1.00        65
#            9       1.00      1.00      1.00        33
#
#     accuracy                           1.00       500
#    macro avg       1.00      1.00      1.00       500
# weighted avg       1.00      1.00      1.00       500
