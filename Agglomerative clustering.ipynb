# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import normalize
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
df = pd.read_csv('./cancer_patient.csv')
#df.drop('index', 'Patient Id', axis=1, inplace=True)
df.drop(['index', 'Patient Id'], axis=1, inplace=True)
df.sample(15)
# Out:
#      Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 206   26       1              6            7             7
# 898   48       1              6            7             7
# 543   29       2              4            5             6
# 823   28       1              6            7             7
# 122   64       1              6            8             7
# 136   65       1              6            8             7
# 680   27       2              3            1             4
# 653   19       1              6            8             7
# 376   17       2              1            2             3
# 230   35       1              4            5             6
# 301   42       1              2            1             2
# 954   45       1              3            2             4
# 644   45       1              6            7             7
# 751   38       2              1            2             3
# 943   47       2              2            3             1
#
#      OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 206                     7             6                     7              7
# 898                     7             7                     6              7
# 543                     5             5                     4              6
# 823                     7             7                     6              7
# 122                     7             7                     6              7
# 136                     7             7                     6              2
# 680                     2             3                     2              3
# 653                     7             7                     6              7
# 376                     4             4                     3              2
# 230                     5             6                     5              5
# 301                     3             4                     3              2
# 954                     2             3                     2              3
# 644                     7             7                     6              7
# 751                     4             2                     4              3
# 943                     3             2                     5              2
#
#      Obesity  ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# 206        7  ...        4            2                    3         1
# 898        7  ...        5            3                    2         7
# 543        7  ...        8            7                    9         2
# 823        7  ...        5            3                    2         7
# 122        7  ...        9            6                    5         7
# 136        4  ...        2            7                    6         5
# 680        3  ...        2            2                    3         4
# 653        7  ...        9            6                    5         7
# 376        1  ...        1            3                    3         2
# 230        5  ...        1            4                    3         2
# 301        1  ...        1            1                    1         2
# 954        3  ...        4            5                    6         5
# 644        7  ...        4            4                    5         6
# 751        3  ...        4            1                    2         4
# 943        1  ...        3            2                    1         2
#
#      Swallowing Difficulty  Clubbing of Finger Nails  Frequent Cold  \
# 206                      4                         5              6
# 898                      8                         2              4
# 543                      1                         4              6
# 823                      8                         2              4
# 122                      2                         4              3
# 136                      1                         9              3
# 680                      1                         5              2
# 653                      2                         4              3
# 376                      1                         3              2
# 230                      4                         6              2
# 301                      1                         2              3
# 954                      5                         4              6
# 644                      5                         5              4
# 751                      6                         5              4
# 943                      3                         1              3
#
#      Dry Cough  Snoring   Level
# 206          7        5    High
# 898          5        3    High
# 543          7        2    High
# 823          5        3    High
# 122          1        4    High
# 136          4        2  Medium
# 680          6        2     Low
# 653          1        4    High
# 376          1        1     Low
# 230          4        1  Medium
# 301          1        2     Low
# 954          5        4  Medium
# 644          6        5    High
# 751          2        5  Medium
# 943          4        2     Low
#
# [15 rows x 24 columns]

# %%
df = df.drop(['Level'], axis=1)
df.head()
# Out:
#    Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   33       1              2            4             5
# 1   17       1              3            1             5
# 2   35       1              4            5             6
# 3   37       1              7            7             7
# 4   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    Obesity  ...  Coughing of Blood  Fatigue  Weight Loss  Shortness of Breath  \
# 0        4  ...                  4        3            4                    2
# 1        2  ...                  3        1            3                    7
# 2        7  ...                  8        8            7                    9
# 3        7  ...                  8        4            2                    3
# 4        7  ...                  9        3            2                    4
#
#    Wheezing  Swallowing Difficulty  Clubbing of Finger Nails  Frequent Cold  \
# 0         2                      3                         1              2
# 1         8                      6                         2              1
# 2         2                      1                         4              6
# 3         1                      4                         5              6
# 4         1                      4                         2              4
#
#    Dry Cough  Snoring
# 0          3        4
# 1          7        2
# 2          7        2
# 3          7        5
# 4          2        3
#
# [5 rows x 23 columns]

# %%
normalized = normalize(df)
normalized[:3]
# Out:
# array([[0.91915231, 0.0278531 , 0.0557062 , 0.1114124 , 0.1392655 ,
#         0.1114124 , 0.0835593 , 0.0557062 , 0.0557062 , 0.1114124 ,
#         0.0835593 , 0.0557062 , 0.0557062 , 0.1114124 , 0.0835593 ,
#         0.1114124 , 0.0557062 , 0.0557062 , 0.0835593 , 0.0278531 ,
#         0.0557062 , 0.0835593 , 0.1114124 ],
#        [0.68718427, 0.0404226 , 0.12126781, 0.0404226 , 0.20211302,
#         0.12126781, 0.16169042, 0.08084521, 0.08084521, 0.08084521,
#         0.08084521, 0.16169042, 0.08084521, 0.12126781, 0.0404226 ,
#         0.12126781, 0.28295823, 0.32338083, 0.24253563, 0.08084521,
#         0.0404226 , 0.28295823, 0.08084521],
#        [0.81351363, 0.02324325, 0.09297299, 0.11621623, 0.13945948,
#         0.11621623, 0.11621623, 0.09297299, 0.13945948, 0.16270273,
#         0.04648649, 0.06972974, 0.09297299, 0.18594597, 0.18594597,
#         0.16270273, 0.20918922, 0.04648649, 0.02324325, 0.09297299,
#         0.13945948, 0.16270273, 0.04648649]])

# %%
df2 = pd.DataFrame(normalized)
df2.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.919152  0.027853  0.055706  0.111412  0.139266  0.111412  0.083559
# 1  0.687184  0.040423  0.121268  0.040423  0.202113  0.121268  0.161690
# 2  0.813514  0.023243  0.092973  0.116216  0.139459  0.116216  0.116216
# 3  0.799638  0.021612  0.151283  0.151283  0.151283  0.151283  0.129671
# 4  0.866230  0.018831  0.112987  0.150649  0.131818  0.131818  0.131818
#
#          7         8         9   ...        13        14        15        16  \
# 0  0.055706  0.055706  0.111412  ...  0.111412  0.083559  0.111412  0.055706
# 1  0.080845  0.080845  0.080845  ...  0.121268  0.040423  0.121268  0.282958
# 2  0.092973  0.139459  0.162703  ...  0.185946  0.185946  0.162703  0.209189
# 3  0.151283  0.151283  0.151283  ...  0.172895  0.086447  0.043224  0.064836
# 4  0.112987  0.131818  0.131818  ...  0.169480  0.056493  0.037662  0.075324
#
#          17        18        19        20        21        22
# 0  0.055706  0.083559  0.027853  0.055706  0.083559  0.111412
# 1  0.323381  0.242536  0.080845  0.040423  0.282958  0.080845
# 2  0.046486  0.023243  0.092973  0.139459  0.162703  0.046486
# 3  0.021612  0.086447  0.108059  0.129671  0.151283  0.108059
# 4  0.018831  0.075324  0.037662  0.075324  0.037662  0.056493
#
# [5 rows x 23 columns]

# %%
df2.columns = df.columns
df2.head()
# Out:
#         Age    Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0  0.919152  0.027853       0.055706     0.111412      0.139266
# 1  0.687184  0.040423       0.121268     0.040423      0.202113
# 2  0.813514  0.023243       0.092973     0.116216      0.139459
# 3  0.799638  0.021612       0.151283     0.151283      0.151283
# 4  0.866230  0.018831       0.112987     0.150649      0.131818
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0              0.111412      0.083559              0.055706       0.055706
# 1              0.121268      0.161690              0.080845       0.080845
# 2              0.116216      0.116216              0.092973       0.139459
# 3              0.151283      0.129671              0.151283       0.151283
# 4              0.131818      0.131818              0.112987       0.131818
#
#     Obesity  ...  Coughing of Blood   Fatigue  Weight Loss  \
# 0  0.111412  ...           0.111412  0.083559     0.111412
# 1  0.080845  ...           0.121268  0.040423     0.121268
# 2  0.162703  ...           0.185946  0.185946     0.162703
# 3  0.151283  ...           0.172895  0.086447     0.043224
# 4  0.131818  ...           0.169480  0.056493     0.037662
#
#    Shortness of Breath  Wheezing  Swallowing Difficulty  \
# 0             0.055706  0.055706               0.083559
# 1             0.282958  0.323381               0.242536
# 2             0.209189  0.046486               0.023243
# 3             0.064836  0.021612               0.086447
# 4             0.075324  0.018831               0.075324
#
#    Clubbing of Finger Nails  Frequent Cold  Dry Cough   Snoring
# 0                  0.027853       0.055706   0.083559  0.111412
# 1                  0.080845       0.040423   0.282958  0.080845
# 2                  0.092973       0.139459   0.162703  0.046486
# 3                  0.108059       0.129671   0.151283  0.108059
# 4                  0.037662       0.075324   0.037662  0.056493
#
# [5 rows x 23 columns]

# %%
# Perform hierarchical clustering
mergings = linkage(normalized, method='ward')

# %%
mergings[:5]
# Out:
# array([[  0.,  33.,   0.,   2.],
#        [  1.,  16.,   0.,   2.],
#        [  2.,   5.,   0.,   2.],
#        [  3., 115.,   0.,   2.],
#        [  4., 204.,   0.,   2.]])

# %%
plt.figure(figsize=(12, 8))

dendrogram(mergings, leaf_rotation=90, leaf_font_size=5)
plt.savefig('./images/dendogram.png')
plt.show()

# %%
# Generate cluster labels with sklearn.cluster's AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters=3, linkage='ward')

labels = cluster.fit_predict(df2)

# %%
# Create a scatter plot with two of the features
plt.scatter(df2['Coughing of Blood'], df2['Shortness of Breath'], c=labels)
plt.savefig('./images/two_feature_scatterplot.png')
plt.show()

# %%
plt.scatter(df2['Wheezing'], df2['Alcohol use'], c=labels)
plt.show()
