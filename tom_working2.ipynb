# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, Normalizer
from sklearn.decomposition import PCA as sklearnPCA

# Suppress unnecessary warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('./cancer_patient.csv')
df.drop(['index', 'Patient Id'], axis=1, inplace=True)
df.head()
# Out:
#    Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0   33       1              2            4             5
# 1   17       1              3            1             5
# 2   35       1              4            5             6
# 3   37       1              7            7             7
# 4   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    Obesity  ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# 0        4  ...        3            4                    2         2
# 1        2  ...        1            3                    7         8
# 2        7  ...        8            7                    9         2
# 3        7  ...        4            2                    3         1
# 4        7  ...        3            2                    4         1
#
#    Swallowing Difficulty  Clubbing of Finger Nails  Frequent Cold  Dry Cough  \
# 0                      3                         1              2          3
# 1                      6                         2              1          7
# 2                      1                         4              6          7
# 3                      4                         5              6          7
# 4                      4                         2              4          2
#
#    Snoring   Level
# 0        4     Low
# 1        2  Medium
# 2        2    High
# 3        5    High
# 4        3    High
#
# [5 rows x 24 columns]

# %%
sns.set_palette("Set3")
from matplotlib import style
style.use("ggplot")

# %%
df.Level = df.Level.replace('Low', 0)
df.Level = df.Level.replace('Medium', 1)
df.Level = df.Level.replace('High', 2)
df.Level = df.Level.astype('int64')

X = df.drop('Level', axis=1)
y = pd.get_dummies(df['Level'])

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_scaled = sc.fit_transform(X)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation

model = Sequential()

model.add(Dense(8, activation = "relu", input_dim = X.shape[1]))
model.add(Dense(16, activation = "relu"))
model.add(Dropout(0.1))
model.add(Dense(8, activation = "relu"))
model.add(Dense(3, activation = "softmax"))

model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["accuracy"])
history = model.fit(X, y, epochs = 40, validation_split = 0.3)
# Out:
# Epoch 1/40
# 22/22 [==============================] - 1s 28ms/step - loss: 2.0110 - accuracy: 0.3471 - val_loss: 1.0463 - val_accuracy: 0.4100
# Epoch 2/40
# 22/22 [==============================] - 0s 3ms/step - loss: 1.3428 - accuracy: 0.3800 - val_loss: 0.9355 - val_accuracy: 0.4900
# Epoch 3/40
# 22/22 [==============================] - 0s 4ms/step - loss: 1.1435 - accuracy: 0.4357 - val_loss: 0.8721 - val_accuracy: 0.5467
# Epoch 4/40
# 22/22 [==============================] - 0s 3ms/step - loss: 1.0517 - accuracy: 0.4671 - val_loss: 0.8370 - val_accuracy: 0.5600
# Epoch 5/40
# 22/22 [==============================] - 0s 4ms/step - loss: 0.9754 - accuracy: 0.4757 - val_loss: 0.8151 - val_accuracy: 0.5300
# Epoch 6/40
# 22/22 [==============================] - 0s 3ms/step - loss: 0.9383 - accuracy: 0.4957 - val_loss: 0.7926 - val_accuracy: 0.5633
# Epoch 7/40
# 22/22 [==============================] - 0s 3ms/step - loss: 0.8946 - accuracy: 0.5257 - val_loss: 0.7723 - val_accuracy: 0.5633
# Epoch 8/40
# 22/22 [==============================] - 0s 3ms/step - loss: 0.8961 - accuracy: 0.5086 - val_loss: 0.7570 - val_accuracy: 0.5933
# Epoch 9/40
# 22/22 [==============================] - 0s 3ms/step - loss: 0.8793 - accuracy: 0.5557 - val_loss: 0.7393 - val_accuracy: 0.6000
# Epoch 10/40
# 22/22 [==============================] - 0s 4ms/step - loss: 0.8696 - accuracy: 0.5529 - val_loss: 0.7272 - val_accuracy: 0.6067
# Epoch 11/40
# 22/22 [==============================] - 0s 3ms/step - loss: 0.8253 - accuracy: 0.5586 - val_loss: 0.7165 - val_accuracy: 0.6000
# Epoch 12/40
# 22/22 [==============================] - 0s 4ms/step - loss: 0.8102 - accuracy: 0.5814 - val_loss: 0.6986 - val_accuracy: 0.6200
# Epoch 13/40
# 22/22 [==============================] - 0s 4ms/step - loss: 0.7969 - accuracy: 0.5929 - val_loss: 0.6863 - val_accuracy: 0.6367
# Epoch 14/40
# 22/22 [==============================] - 0s 4ms/step - loss: 0.7784 - accuracy: 0.5743 - val_loss: 0.6722 - val_accuracy: 0.6733
# Epoch 15/40
# 22/22 [==============================] - 0s 4ms/step - loss: 0.7706 - accuracy: 0.6129 - val_loss: 0.6582 - val_accuracy: 0.6800
# Epoch 16/40
# 22/22 [==============================] - 0s 5ms/step - loss: 0.7645 - accuracy: 0.6129 - val_loss: 0.6461 - val_accuracy: 0.6800
# Epoch 17/40
# 22/22 [==============================] - 0s 6ms/step - loss: 0.7411 - accuracy: 0.6400 - val_loss: 0.6360 - val_accuracy: 0.7133
# Epoch 18/40
# 22/22 [==============================] - 0s 6ms/step - loss: 0.7333 - accuracy: 0.6471 - val_loss: 0.6246 - val_accuracy: 0.7067
# Epoch 19/40
# 22/22 [==============================] - 0s 5ms/step - loss: 0.7116 - accuracy: 0.6557 - val_loss: 0.6135 - val_accuracy: 0.7133
# Epoch 20/40
# 22/22 [==============================] - 0s 4ms/step - loss: 0.7023 - accuracy: 0.6729 - val_loss: 0.6023 - val_accuracy: 0.7400
# Epoch 21/40
# 22/22 [==============================] - 0s 5ms/step - loss: 0.6990 - accuracy: 0.6457 - val_loss: 0.5916 - val_accuracy: 0.7133
# Epoch 22/40
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6715 - accuracy: 0.6786 - val_loss: 0.5767 - val_accuracy: 0.7400
# Epoch 23/40
# 22/22 [==============================] - 0s 6ms/step - loss: 0.6580 - accuracy: 0.6986 - val_loss: 0.5681 - val_accuracy: 0.7700
# Epoch 24/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6368 - accuracy: 0.7043 - val_loss: 0.5543 - val_accuracy: 0.7667
# Epoch 25/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6344 - accuracy: 0.7100 - val_loss: 0.5472 - val_accuracy: 0.8000
# Epoch 26/40
# 22/22 [==============================] - 0s 8ms/step - loss: 0.6259 - accuracy: 0.7229 - val_loss: 0.5351 - val_accuracy: 0.7667
# Epoch 27/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6198 - accuracy: 0.7243 - val_loss: 0.5255 - val_accuracy: 0.7967
# Epoch 28/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6081 - accuracy: 0.7257 - val_loss: 0.5149 - val_accuracy: 0.7933
# Epoch 29/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.6122 - accuracy: 0.7171 - val_loss: 0.5063 - val_accuracy: 0.7933
# Epoch 30/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5970 - accuracy: 0.7414 - val_loss: 0.4985 - val_accuracy: 0.8067
# Epoch 31/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5731 - accuracy: 0.7500 - val_loss: 0.4890 - val_accuracy: 0.8067
# Epoch 32/40
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5684 - accuracy: 0.7414 - val_loss: 0.4854 - val_accuracy: 0.8067
# Epoch 33/40
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5639 - accuracy: 0.7500 - val_loss: 0.4757 - val_accuracy: 0.8000
# Epoch 34/40
# 22/22 [==============================] - 0s 7ms/step - loss: 0.5469 - accuracy: 0.7586 - val_loss: 0.4657 - val_accuracy: 0.8167
# Epoch 35/40
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5392 - accuracy: 0.7657 - val_loss: 0.4555 - val_accuracy: 0.8067
# Epoch 36/40
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5407 - accuracy: 0.7486 - val_loss: 0.4449 - val_accuracy: 0.8067
# Epoch 37/40
# 22/22 [==============================] - 0s 6ms/step - loss: 0.5227 - accuracy: 0.7700 - val_loss: 0.4386 - val_accuracy: 0.8267
# Epoch 38/40
# 22/22 [==============================] - 0s 5ms/step - loss: 0.5121 - accuracy: 0.7714 - val_loss: 0.4253 - val_accuracy: 0.8033
# Epoch 39/40
# 22/22 [==============================] - 0s 5ms/step - loss: 0.4969 - accuracy: 0.7771 - val_loss: 0.4189 - val_accuracy: 0.8367
# Epoch 40/40
# 22/22 [==============================] - 0s 5ms/step - loss: 0.4829 - accuracy: 0.7971 - val_loss: 0.4114 - val_accuracy: 0.8333

# %%
plt.figure(figsize = (8,5))
plt.plot(history.history["loss"], color = "r", label= "Training loss", marker = "o")
plt.plot(history.history["val_loss"], color = "b", label= "Validation loss", marker = "o")
plt.title("Training VS Validation loss", fontsize = 20)
plt.xlabel("No. of Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ### Checking accuracies in the model

# %%
plt.figure(figsize = (8,5))
plt.plot(history.history["accuracy"], color = "r", label = "Training accuracy", marker = "o")
plt.plot(history.history["val_accuracy"], color = "b", label = "Validation accuracy", marker = "o")
plt.title("Training VS Validation Accuracy", fontsize = 20)
plt.xlabel("No. of Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
#!pip3 install ann_visualizer

#!pip3 install graphviz

#from ann_visualizer.visualize import ann_viz

#ann_viz(model, view = True)#, filename = "ann.png")
